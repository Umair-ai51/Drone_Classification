# %% [markdown]
# <a href="https://colab.research.google.com/github/Umair-ai51/Drone_Classification/blob/main/Drone_Classification_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, GRU, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.callbacks import EarlyStopping

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_11.csv')
df2_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_12.csv')
df3_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_13.csv')
df4_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_14.csv')
df5_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_15.csv')
df6_auth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_16.csv')

df1_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_17.csv')
df2_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_18.csv')
df3_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_18.csv')
df4_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_19.csv')
df5_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_20.csv')
df6_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_21.csv')
df7_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_22.csv')
df8_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_23.csv')
df9_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_24.csv')
df10_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_25.csv')
df11_unauth = pd.read_csv('/content/drive/MyDrive/Internship/Deep_Learning_Sesnor_Based_Model/Sensor_Data_V2/sensor_data_AutoReg_26.csv')

# %%
df_authorized = pd.concat([df1_auth, df2_auth, df3_auth, df4_auth, df5_auth, df6_auth])

df_unauthorized = pd.concat([df1_unauth, df2_unauth, df3_unauth, df4_unauth, df5_unauth, df6_unauth, df7_unauth, df8_unauth, df9_unauth, df10_unauth, df11_unauth])

# %%
df_authorized.describe()
# Out:
#                Time    OrgTrans_X    ModTrans_X    OrgTrans_Y    ModTrans_Y  \
# count  24008.000000  24008.000000  24008.000000  24008.000000  24008.000000
# mean     150.000000    464.382068    464.382055    475.956145    475.956130
# std       86.633207    315.854695    315.854690    259.057985    259.057980
# min        0.000000    -40.234082    -40.234082    -59.696964    -59.696964
# 25%       75.000000    197.798683    197.798663    298.520508    298.520501
# 50%      150.000000    405.592012    405.592003    493.523170    493.523165
# 75%      225.000000    683.470321    683.470296    675.290970    675.290959
# max      300.000000   1301.865602   1301.865602   1200.000000   1200.000000
#
#          OrgTrans_Z    ModTrans_Z      OrgRot_w      ModRot_w      OrgRot_x  \
# count  24008.000000  24008.000000  24008.000000  24008.000000  24008.000000
# mean     238.114216    238.114208      0.256974      0.256974     -0.005960
# ...

# %%
df_unauthorized.head()
# Out:
#    Time   OrgTrans_X   ModTrans_X   OrgTrans_Y   ModTrans_Y   OrgTrans_Z  \
# 0   0.0  1300.000000  1300.000000  1100.000000  1100.000000   280.000000
# 1   0.1  1300.106702  1300.106702  1098.927466  1098.927466   280.153982
# 2   0.2  1300.210186  1300.210186  1097.858519  1097.858519   280.307026
# 3   0.3  1300.310460  1300.310460  1096.793152  1096.793152   280.459134
# 4   0.4  1300.407529  1300.407529  1095.731359  1095.731359   280.610306
#
#     ModTrans_Z   OrgRot_w   ModRot_w   OrgRot_x  ...  Radar_Velocity  \
# 0   280.000000        0.0        0.0        0.0  ...        0.171312
# 1   280.153982        0.0        0.0        0.0  ...       -5.792671
# 2   280.307026        0.0        0.0        0.0  ...       -4.981833
# 3   280.459134        0.0        0.0        0.0  ...       -5.361170
# 4   280.610306        0.0        0.0        0.0  ...       -6.066450
#
#    Radar_Range  Acoustic_Signal  Tracking_Error   Optical_Error   VBAKF_Error  \
# ...

# %%
df_authorized['Type'] = df_authorized.apply(lambda x: 0, axis=1)
df_authorized.shape
# Out:
# (18006, 26)

# %%
df_unauthorized['Type'] = df_unauthorized.apply(lambda x: 1, axis=1)
df_unauthorized.shape
# Out:
# (33011, 26)

# %%
df_authorized.head()
# Out:
#    Time   OrgTrans_X   ModTrans_X   OrgTrans_Y   ModTrans_Y   OrgTrans_Z  \
# 0   0.0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1   0.1     1.053622     1.053622    -0.401927    -0.401927     0.739700
# 2   0.2     2.095299     2.095299    -0.799760    -0.799760     1.477978
# 3   0.3     3.125078     3.125078    -1.193510    -1.193510     2.214835
# 4   0.4     4.143003     4.143003    -1.583190    -1.583190     2.950270
#
#     ModTrans_Z   OrgRot_w   ModRot_w   OrgRot_x  ...  Radar_Range  \
# 0     0.000000   0.707107   0.707107   0.000000  ...     1.256641
# 1     0.739700   0.109350   0.109350  -0.695991  ...     2.900066
# 2     1.477978   0.109901   0.109901  -0.693314  ...     4.454615
# 3     2.214835   0.110449   0.110449  -0.690657  ...     3.413174
# 4     2.950270   0.110992   0.110992  -0.688022  ...     9.476854
#
#    Acoustic_Signal  Tracking_Error   Optical_Error   VBAKF_Error   vbakf_x  \
# ...

# %%
df_unauthorized.head()
# Out:
#    Time   OrgTrans_X   ModTrans_X   OrgTrans_Y   ModTrans_Y   OrgTrans_Z  \
# 0   0.0  1300.000000  1300.000000  1100.000000  1100.000000   280.000000
# 1   0.1  1300.106702  1300.106702  1098.927466  1098.927466   280.153982
# 2   0.2  1300.210186  1300.210186  1097.858519  1097.858519   280.307026
# 3   0.3  1300.310460  1300.310460  1096.793152  1096.793152   280.459134
# 4   0.4  1300.407529  1300.407529  1095.731359  1095.731359   280.610306
#
#     ModTrans_Z   OrgRot_w   ModRot_w   OrgRot_x  ...  Radar_Range  \
# 0   280.000000        0.0        0.0        0.0  ...  1720.522917
# 1   280.153982        0.0        0.0        0.0  ...  1728.010753
# 2   280.307026        0.0        0.0        0.0  ...  1727.439056
# 3   280.459134        0.0        0.0        0.0  ...  1719.641476
# 4   280.610306        0.0        0.0        0.0  ...  1731.553018
#
#    Acoustic_Signal  Tracking_Error   Optical_Error   VBAKF_Error      vbakf_x  \
# ...

# %%
df_combined = pd.concat([df_authorized,df_unauthorized])
df_combined
# Out:
#        Time   OrgTrans_X   ModTrans_X   OrgTrans_Y   ModTrans_Y   OrgTrans_Z  \
# 0       0.0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1       0.1     1.053622     1.053622    -0.401927    -0.401927     0.739700
# 2       0.2     2.095299     2.095299    -0.799760    -0.799760     1.477978
# 3       0.3     3.125078     3.125078    -1.193510    -1.193510     2.214835
# 4       0.4     4.143003     4.143003    -1.583190    -1.583190     2.950270
# ...     ...          ...          ...          ...          ...          ...
# 2996  299.6   598.089576   598.089524   797.760181   797.760111   231.426587
# 2997  299.7   598.571573   598.571560   798.320683   798.320665   231.071678
# 2998  299.8   599.050651   599.050440   798.880820   798.880539   230.715612
# 2999  299.9   599.526797   599.526795   799.440593   799.440590   230.358386
# 3000  300.0   600.000000   599.999847   800.000000   799.999796   230.000000
#
# ...

# %%
df_combined.columns
# Out:
# Index(['Time', ' OrgTrans_X', ' ModTrans_X', ' OrgTrans_Y', ' ModTrans_Y',
#        ' OrgTrans_Z', ' ModTrans_Z', ' OrgRot_w', ' ModRot_w', ' OrgRot_x',
#        'ModRot_x', ' OrgRot_y', ' ModRot_y', ' OrgRot_z ', 'ModRot_z',
#        'Radar_Velocity', 'Radar_Range', 'Acoustic_Signal', 'Tracking_Error',
#        ' Optical_Error', ' VBAKF_Error', ' vbakf_x', ' vbakf_y', ' optical_x',
#        ' optical_y', 'Type'],
#       dtype='object')

# %%
X = df_combined[['Time', ' OrgTrans_X', ' ModTrans_X', ' OrgTrans_Y', ' ModTrans_Y',
       ' OrgTrans_Z', ' ModTrans_Z', ' OrgRot_w', ' ModRot_w', ' OrgRot_x',
       'ModRot_x', ' OrgRot_y', ' ModRot_y', ' OrgRot_z ', 'ModRot_z',
       'Radar_Velocity', 'Radar_Range', 'Acoustic_Signal', 'Tracking_Error',
       ' Optical_Error', ' VBAKF_Error', ' vbakf_x', ' vbakf_y', ' optical_x',
       ' optical_y']]

y = df_combined['Type']

# %%
def prepare_sequences(X, sequence_length=10):
    """
    Prepare sequences for LSTM by creating windows of data
    """
    features = []
    for i in range(len(X) - sequence_length):
        features.append(X[i:(i + sequence_length)])
    return np.array(features)

# %%
important_features = ['Time', ' OrgTrans_X', ' ModTrans_X', ' OrgTrans_Y',
                     ' ModTrans_Y', ' OrgTrans_Z', ' ModTrans_Z']
X_important = X[important_features]

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_important)

# Prepare sequences
sequence_length = 10  # You can adjust this based on your needs
X_sequences = prepare_sequences(X_scaled, sequence_length)
y_sequences = y[sequence_length:]  # Adjust labels to match sequence length

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_sequences, y_sequences, test_size=0.2, random_state=42, shuffle=False
)

# %%
def create_lstm_model(input_shape):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
model = create_lstm_model(input_shape)

# Define early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1021/1021 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.8640 - loss: 0.2640 - val_accuracy: 0.5754 - val_loss: 2.9416
# Epoch 2/50
# 1021/1021 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9714 - loss: 0.0634 - val_accuracy: 0.5699 - val_loss: 3.4393
# Epoch 3/50
# 1021/1021 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.9886 - loss: 0.0305 - val_accuracy: 0.5599 - val_loss: 3.4232
# Epoch 4/50
# 1021/1021 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9943 - loss: 0.0168 - val_accuracy: 0.5396 - val_loss: 4.0552
# Epoch 5/50
# 1021/1021 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9953 - loss: 0.0154 - val_accuracy: 0.5416 - val_loss: 3.8678
# Epoch 6/50
# ...
